# %%
#### Importing Packages and uploading data ####

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('Verkada_Data.csv', sep=';')

# %%
#### Cleaning Data ####

# mql_created_date_mod

def modify_date(original_date):
    if len(original_date.split('/')[1])==1:
        return '0'+original_date.split('/')[1]+'/04/2019'
    else:
        return original_date.split('/')[1]+'/04/2019'

data['mql_created_date_mod'] = pd.to_datetime(data['mql_created_date'].apply(lambda x: modify_date(x)), format='%d/%m/%Y')

# source_renamed

data['source_renamed'] = pd.Series(np.where(data['source']=='Email','01. Email',\
          np.where(data['source']=='Direct Mail','02. Direct Mail',\
          np.where(data['source']=='Paid Social','03. Paid Social','04. Other'))))

# week_of_month

conditions_week_of_month = [
    data['mql_created_date_mod']<='2019-04-07',
    (data['mql_created_date_mod']>'2019-04-07') & (data['mql_created_date_mod']<='2019-04-14'),
    (data['mql_created_date_mod']>'2019-04-14') & (data['mql_created_date_mod']<='2019-04-21'),
    data['mql_created_date_mod']>'2019-04-21'
]
choices_week_of_month = ['01. First Week','02. Second Week','03. Third Week','04. Fourth Week']

data['week_of_month'] = pd.Series(np.select(conditions_week_of_month, choices_week_of_month))

# flg_sql

data['flg_sql'] = pd.Series(np.where(data['client_status']=='SQL',1,0))

# flg_mql_ever

data['flg_mql_ever'] = 1

# %%
#### Exploring Data ####

exploring_data_list = ['client_status','source','source_renamed','mql_created_date_mod','flg_sql','flg_mql_ever','week_of_month']

for i in exploring_data_list:
    percentages = (data[i].value_counts(normalize=True).to_frame('percentage')*100).round(1)
    counts = data[i].value_counts().to_frame('counts')
    table = pd.concat([percentages, counts], axis=1).rename_axis(i).reset_index().sort_values(i).reset_index(drop=True) 
    print(table,'\n')
# Out:
#   client_status  percentage  counts
# 0           MQL        61.0    1318
# 1           SQL        39.0     841
#
#         source  percentage  counts
# 0  Direct Mail        15.5     334
# 1        Email        13.6     293
# 2        Other         0.9      20
# 3  Paid Social        70.0    1512
#
#     source_renamed  percentage  counts
# 0        01. Email        13.6     293
# 1  02. Direct Mail        15.5     334
# 2  03. Paid Social        70.0    1512
# 3        04. Other         0.9      20
#
#    mql_created_date_mod  percentage  counts
# 0            2019-04-01         0.9      19
# 1            2019-04-02         0.3       7
# 2            2019-04-03         2.2      48
# 3            2019-04-04         0.3       7
# 4            2019-04-05         0.2       5
# 5            2019-04-06         0.4       8
# 6            2019-04-07         0.1       2
# 7            2019-04-08         0.2       4
# 8            2019-04-09         0.3       7
# ...

# %%
#### Questions 1 and 2 ####

# Table
q1_q2_tmp_table = data.groupby('week_of_month').agg(MQL= ('flg_mql_ever', 'sum'),SQL= ('flg_sql', 'sum'))
q1_q2_tmp_table['conversion_rate'] = (q1_q2_tmp_table['SQL']/q1_q2_tmp_table['MQL']*100).round(0)
q1_q2_tmp_table['percentage_mql'] = (q1_q2_tmp_table['MQL']/q1_q2_tmp_table['MQL'].sum()*100).round(0)

print(q1_q2_tmp_table)

## Plot

# Setting initial variables
week_of_month = q1_q2_tmp_table.index 
MQL = q1_q2_tmp_table.iloc[:,0]
SQL = q1_q2_tmp_table.iloc[:,1]
conversion_rate = q1_q2_tmp_table.iloc[:,2]
    
# Figure and Axis
fig, ax1 = plt.subplots()

# Width of the bars
bar_width = 0.35

# Positions for MQL and SQL bars
bar_positions_MQL = np.arange(len(week_of_month))
bar_positions_SQL = bar_positions_MQL + bar_width

# Plot unstacked bars for MQL and SQL on the primary axis
ax1.bar(bar_positions_MQL, MQL, width=bar_width, label='MQL', color='green', alpha=0.1, bottom=0)
ax1.bar(bar_positions_SQL, SQL, width=bar_width, label='SQL', color='gray', alpha=0.7, bottom=0)

# MQL values above the bars
for i, value in enumerate(MQL):
    ax1.text(bar_positions_MQL[i] + bar_width / 2-0.17, value, str(value), ha='center', va='bottom')

# SQL values above the bars
for i, value in enumerate(SQL):
    ax1.text(bar_positions_SQL[i] + bar_width / 2-0.17, SQL[i], str(value), ha='center', va='bottom')
    
# Secondary y-axis for conversion_rate
ax2 = ax1.twinx()
ax2.plot(week_of_month, conversion_rate, label='Conversion Rate', marker='s', color='orange')

# conversion_rate values above the line
for i, value in enumerate(conversion_rate):
    ax2.text(week_of_month[i], value+0.1, f'{value:.1f}%', ha='center', va='bottom')

# Secondary y-axis limits to start at 0
ax2.set_ylim(bottom=0, top=100)
    
# Set labels and title
ax1.set_xlabel('Week of Month')
ax1.set_ylabel('MQL and SQL', color='black')
ax2.set_ylabel('Conversion Rate', color='black')
ax1.set_title('Evolution of MQL, SQL, and Conversion Rate per Week - April 2019', y=1.05)

# Set the x-axis ticks and labels
ax1.set_xticks(bar_positions_MQL + bar_width / 2)
ax1.set_xticklabels(week_of_month)

# Combine legends below the graph
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

# Show the plot
plt.show()
plt.clf()
# Out:
#                   MQL  SQL  conversion_rate  percentage_mql
# week_of_month
# 01. First Week     96   45             47.0             4.0
# 02. Second Week   136   64             47.0             6.0
# 03. Third Week    408  137             34.0            19.0
# 04. Fourth Week  1519  595             39.0            70.0

# %%
#### Question 3 - Analysis 1 ####

# Table
q3_a1_tmp_table = data.groupby('source_renamed').agg(MQL= ('flg_mql_ever', 'sum'),SQL= ('flg_sql', 'sum'))
q3_a1_tmp_table['conversion_rate'] = (q3_a1_tmp_table['SQL']/q3_a1_tmp_table['MQL']*100).round(0)
q3_a1_tmp_table['percentage_mql'] = (q3_a1_tmp_table['MQL']/q3_a1_tmp_table['MQL'].sum()*100).round(0)

print(q3_a1_tmp_table)

## Plot

# Setting initial variables
source_renamed = q3_a1_tmp_table.index 
MQL = q3_a1_tmp_table.iloc[:,0]
SQL = q3_a1_tmp_table.iloc[:,1]
conversion_rate = q3_a1_tmp_table.iloc[:,2]

# Create figure and axis
fig, ax1 = plt.subplots()

# Width of the bars
bar_width = 0.35

# Positions for MQL and SQL bars
bar_positions_MQL = np.arange(len(source_renamed))
bar_positions_SQL = bar_positions_MQL + bar_width

# Plot unstacked bars for MQL and SQL on the primary axis
ax1.bar(bar_positions_MQL, MQL, width=bar_width, label='MQL', color='green', alpha=0.1, bottom=0)
ax1.bar(bar_positions_SQL, SQL, width=bar_width, label='SQL', color='gray', alpha=0.7, bottom=0)


# MQL values above the bars
for i, value in enumerate(MQL):
    ax1.text(bar_positions_MQL[i] + bar_width / 2-0.17, value, str(value), ha='center', va='bottom')

# SQL values above the bars
for i, value in enumerate(SQL):
    ax1.text(bar_positions_SQL[i] + bar_width / 2-0.17, SQL[i], str(value), ha='center', va='bottom')
    
# Secondary y-axis for conversion_rate
ax2 = ax1.twinx()
ax2.plot(source_renamed, conversion_rate, label='Conversion Rate', marker='s', color='orange')

# conversion_rate values above the line
for i, value in enumerate(conversion_rate):
    ax2.text(source_renamed[i], value+0.1, f'{value:.1f}%', ha='center', va='bottom')
    
# Secondary y-axis limits to start at 0
ax2.set_ylim(bottom=0, top=100)
    
# Set labels and title
ax1.set_xlabel('Source')
ax1.set_ylabel('MQL and SQL', color='black')
ax2.set_ylabel('Conversion Rate', color='black')
ax1.set_title('Number of MQL, SQL, and Conversion Rate per Source', y=1.05)

# Set the x-axis ticks and labels
ax1.set_xticks(bar_positions_MQL + bar_width / 2)
ax1.set_xticklabels(source_renamed)

# Combine legends below the graph
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

# Show the plot
plt.show()
plt.clf()
# Out:
#                   MQL  SQL  conversion_rate  percentage_mql
# source_renamed
# 01. Email         293  243             83.0            14.0
# 02. Direct Mail   334  126             38.0            15.0
# 03. Paid Social  1512  463             31.0            70.0
# 04. Other          20    9             45.0             1.0

# %%
#### Question 3 - Analysis 2 ####

#Table

q3_a2_tmp_table_1 = data.pivot_table(values='flg_mql_ever',index='source_renamed', columns='week_of_month', aggfunc='sum', fill_value=0)
q3_a2_tmp_table_2 = pd.DataFrame()

for i in q3_a2_tmp_table_1.index:
    for j in q3_a2_tmp_table_1.columns:
        q3_a2_tmp_table_2.loc[i,j] = q3_a2_tmp_table_1.loc[i,j] / (q3_a2_tmp_table_1.loc[:,j].sum())

q3_a2_tmp_table_2 = (q3_a2_tmp_table_2*100).round(0)        
    
print(q3_a2_tmp_table_2)

## BarPlot

#Transposing
q3_a2_tmp_table_2_transposed = q3_a2_tmp_table_2.transpose()

# Stacked bar plot
q3_a2_tmp_table_2_transposed.plot(kind='bar', stacked=True, color=['blue', 'orange', 'grey', 'yellow'], figsize=(10, 6))

# Labels and title
plt.xlabel('Week of Month')
plt.ylabel('Percentage')
plt.title('Distribution of MQL by Source for each Week')

# Legend
plt.legend(title='Source', bbox_to_anchor=(1, 1), loc='upper left')

# Show the plot
plt.show()
plt.clf()
# Out:
#                  01. First Week  02. Second Week  03. Third Week  \
# 01. Email                  45.0             49.0            12.0
# 02. Direct Mail            11.0             14.0            25.0
# 03. Paid Social            23.0             37.0            63.0
# 04. Other                  21.0              0.0             0.0
#
#                  04. Fourth Week
# 01. Email                    9.0
# 02. Direct Mail             13.0
# 03. Paid Social             78.0
# 04. Other                    0.0

# %%
#### Question 3 - Analysis 3 ####

#Table
q3_a3_tmp_table_1=data.pivot_table(values='flg_mql_ever',index='source_renamed', columns='week_of_month', aggfunc='sum', fill_value=0)
q3_a3_tmp_table_2=data.pivot_table(values='flg_sql',index='source_renamed', columns='week_of_month', aggfunc='sum', fill_value=0)
q3_a3_tmp_table_3 = ((q3_a3_tmp_table_2/q3_a3_tmp_table_1)*100).round(0).fillna(0)

print(q3_a3_tmp_table_3)

## Plot (except Other)

# Transpose
q3_a3_tmp_table_3_transposed = q3_a3_tmp_table_3.iloc[0:3, :].transpose()

# Line plot for each index
ax = q3_a3_tmp_table_3_transposed.plot(kind='line', marker='o', color=['blue', 'orange', 'grey'], figsize=(10, 6))

# Labels and title
plt.xlabel('Week of Month')
plt.ylabel('Percentage')
plt.title('Evolution of conversion rates by source over time')

# Legend
plt.legend(title='Source', bbox_to_anchor=(1, 1), loc='upper left')

# Annotate values on the lines
for column in q3_a3_tmp_table_3_transposed.columns:
    for i, value in enumerate(q3_a3_tmp_table_3_transposed[column]):
        ax.annotate(f'{value:.1f}%', (i, value), textcoords="offset points", xytext=(0, 5), ha='center', va='bottom')

# Show the plot
plt.show()
plt.clf()
# Out:
# week_of_month    01. First Week  02. Second Week  03. Third Week  \
# source_renamed
# 01. Email                  70.0             72.0            84.0
# 02. Direct Mail            18.0             26.0            35.0
# 03. Paid Social            18.0             22.0            23.0
# 04. Other                  45.0              0.0             0.0
#
# week_of_month    04. Fourth Week
# source_renamed
# 01. Email                   93.0
# 02. Direct Mail             41.0
# 03. Paid Social             33.0
# 04. Other                    0.0

# %%
#### Question 4 ####

## Iterating tables and plots for each source

list_of_sources = ['Email','Direct Mail','Paid Social']

for j in list_of_sources:

    #Table
    q4_tmp_table_1 = data[data['source']==j] 
    q4_tmp_table_2 = q4_tmp_table_1.groupby('week_of_month').agg(MQL= ('flg_mql_ever', 'sum'),SQL= ('flg_sql', 'sum'))
    q4_tmp_table_2['conversion_rate'] = (q4_tmp_table_2['SQL']/q4_tmp_table_2['MQL']*100).round(0)
    q4_tmp_table_2['percentage_mql'] = (q4_tmp_table_2['MQL']/q4_tmp_table_2['MQL'].sum()*100).round(0)

    print(q4_tmp_table_2)

    ## Plot

    # Setting initial variables
    week_of_month = q4_tmp_table_2.index 
    MQL = q4_tmp_table_2.iloc[:,0]
    SQL = q4_tmp_table_2.iloc[:,1]
    conversion_rate = q4_tmp_table_2.iloc[:,2]
    
    # Figure and Axis
    fig, ax1 = plt.subplots()

    # Width of the bars
    bar_width = 0.35

    # Positions for MQL and SQL bars
    bar_positions_MQL = np.arange(len(week_of_month))
    bar_positions_SQL = bar_positions_MQL + bar_width

    # Plot unstacked bars for MQL and SQL on the primary axis
    ax1.bar(bar_positions_MQL, MQL, width=bar_width, label='MQL', color='green', alpha=0.1, bottom=0)
    ax1.bar(bar_positions_SQL, SQL, width=bar_width, label='SQL', color='gray', alpha=0.7, bottom=0)


    # Annotate MQL values above the bars
    for i, value in enumerate(MQL):
        ax1.text(bar_positions_MQL[i] + bar_width / 2-0.17, value, str(value), ha='center', va='bottom')

    # Annotate SQL values above the bars
    for i, value in enumerate(SQL):
        ax1.text(bar_positions_SQL[i] + bar_width / 2-0.17, SQL[i], str(value), ha='center', va='bottom')

    # Secondary y-axis for conversion_rate
    ax2 = ax1.twinx()
    ax2.plot(week_of_month, conversion_rate, label='Conversion Rate', marker='s', color='orange')

    # conversion_rate values above the line
    for i, value in enumerate(conversion_rate):
        ax2.text(week_of_month[i], value+0.1, f'{value:.1f}%', ha='center', va='bottom', )

    # Set the secondary y-axis limits to start at 0
    ax2.set_ylim(bottom=0, top=100)
    
    # Set labels and title
    ax1.set_xlabel('Week of Month')
    ax1.set_ylabel('MQL and SQL', color='black')
    ax2.set_ylabel('Conversion Rate', color='black')
    ax1.set_title('Evolution of MQL, SQL, and Conversion Rate per Week - '+j, y=1.05)

    # Set the x-axis ticks and labels
    ax1.set_xticks(bar_positions_MQL + bar_width / 2)
    ax1.set_xticklabels(week_of_month)

    # Combine legends below the graph
    lines, labels = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines + lines2, labels + labels2, loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=3)

    # Show the plot
    plt.show()
    plt.clf()
# Out:
#                  MQL  SQL  conversion_rate  percentage_mql
# week_of_month
# 01. First Week    43   30             70.0            15.0
# 02. Second Week   67   48             72.0            23.0
# 03. Third Week    49   41             84.0            17.0
# 04. Fourth Week  134  124             93.0            46.0
#                  MQL  SQL  conversion_rate  percentage_mql
# week_of_month
# 01. First Week    11    2             18.0             3.0
# 02. Second Week   19    5             26.0             6.0
# 03. Third Week   103   36             35.0            31.0
# 04. Fourth Week  201   83             41.0            60.0
#                   MQL  SQL  conversion_rate  percentage_mql
# week_of_month
# 01. First Week     22    4             18.0             1.0
# 02. Second Week    50   11             22.0             3.0
# 03. Third Week    256   60             23.0            17.0
# 04. Fourth Week  1184  388             33.0            78.0
